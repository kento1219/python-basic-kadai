# %%
list = ["水","金","地","火","木","土","天","海","冥"]

for planet in list:
    print(planet)
# Out:
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥

# %%
list = ["水","金","地","火","木","土","天","海","冥"]
index = 0

while index <= 8:
    print(list[index])
    index = index + 1
# Out:
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
