# %%
import random
var = random.randint(1,100)
print(var)

if var % 15 == 0:
    print("FizzBuzz")
elif var % 3 == 0:
    print("Fizz")
elif var % 5 == 0:
    print("Buzz")
else:
    print(var)
# Out:
# 96
# Fizz
