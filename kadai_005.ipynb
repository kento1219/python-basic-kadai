# %%
d_menseki = (10 + 20)*5/2
t_tani = str(cm2)
print(d_menseki + t_tani)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-159c0c7b41ec> in <cell line: 2>()
#       1 d_menseki = (10 + 20)*5/2
# ----> 2 t_tani = str(cm2)
#       3 print(d_menseki + t_tani)
#
# NameError: name 'cm2' is not defined
