# %%
menseki = (10+20)*5/2
tanni = "cm2"
print(menseki,tanni)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-7139a3d592ae> in <cell line: 3>()
#       1 menseki = (10+20)*5/2
#       2 tanni = "cm2"
# ----> 3 print(menseki+str("tanni"))
#
# TypeError: unsupported operand type(s) for +: 'float' and 'str'
